# %% [markdown]
# <a href="https://colab.research.google.com/github/divyaparadkar/pandas-/blob/main/EDA_using_pythion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data =pd.read_csv("/content/sample_data/california_housing_train.csv")

# %% [markdown]
# first understanding the data

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
data.shape
# Out:
# (17000, 9)

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
data.nunique()
# Out:
# longitude               827
# latitude                840
# housing_median_age       52
# total_rooms            5533
# total_bedrooms         1848
# population             3683
# households             1740
# median_income         11175
# median_house_value     3694
# dtype: int64

# %%
data['longitude'].unique()
# Out:
# array([-114.31, -114.47, -114.56, -114.57, -114.58, -114.59, -114.6 ,
#        -114.61, -114.63, -114.65, -114.66, -114.67, -114.68, -114.73,
#        -114.94, -114.98, -115.22, -115.32, -115.37, -115.38, -115.39,
#        -115.4 , -115.41, -115.46, -115.48, -115.49, -115.5 , -115.51,
#        -115.52, -115.53, -115.54, -115.55, -115.56, -115.57, -115.58,
#        -115.59, -115.6 , -115.62, -115.64, -115.69, -115.72, -115.73,
#        -115.8 , -115.84, -115.85, -115.88, -115.9 , -115.91, -115.93,
#        -115.94, -115.95, -115.96, -115.98, -115.99, -116.  , -116.01,
#        -116.02, -116.05, -116.06, -116.08, -116.09, -116.11, -116.12,
#        -116.14, -116.15, -116.16, -116.17, -116.18, -116.19, -116.2 ,
#        -116.21, -116.22, -116.23, -116.24, -116.25, -116.26, -116.27,
#        -116.29, -116.3 , -116.31, -116.32, -116.33, -116.34, -116.35,
#        -116.36, -116.37, -116.38, -116.39, -116.4 , -116.41, -116.42,
# ...

# %% [markdown]
# #Cleaning the data set

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
california_housing_train=data.drop(['total_rooms','households'], axis=1)

# %% [markdown]
# #3 Relationship analysis

# %%
corelation =california_housing_train.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(california_housing_train)
